# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayeshaaa777/OpenCV/blob/main/OpenCv_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2

# %%
import numpy as np

# %%
# load an image specifying the path to change
input = cv2.imread('/content/download.jpeg')

# %%
# first parameter shown "breaking bad" and the second parameter is the image to be show for
# cv2.imshow(1,2) but it doesnt work on colab instead
# imshow is used in jupyter notebook for google colab import
from google.colab.patches import cv2_imshow
cv2_imshow(input)
#cv2.imshow(input)- it takes only one paramater
# we can also display using matplotlib
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7FCF34CA7340>

# %%
# its just to display after reading
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('/content/download.jpeg')
plt.imshow(img)

# %%
# if u want to apply gray scale, green and stuff
from PIL import Image
fname = r'/content/download.jpeg'
image = Image.open(fname).convert('L')
plt.imshow(image,cmap='gray',vmin=0,vmax=255)
